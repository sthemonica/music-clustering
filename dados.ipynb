# %%
import pandas as pd

# %%
dados = pd.read_csv('spotify/data.csv')
dados_artistas = pd.read_csv('spotify/data_by_artist.csv')
dados_generos = pd.read_csv('spotify/data_by_genres.csv')
dados_anos = pd.read_csv('spotify/data_by_year.csv')
dados_com_genero = pd.read_csv('spotify/data_w_genres.csv')

# %%
dados.head()
# Out:
#    valence  year  acousticness  \
# 0   0.0594  1921         0.982
# 1   0.9630  1921         0.732
# 2   0.0394  1921         0.961
# 3   0.1650  1921         0.967
# 4   0.2530  1921         0.957
#
#                                              artists  danceability  \
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                     ['Dennis Day']         0.819
# 2  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                   ['Frank Parker']         0.275
# 4                                     ['Phil Regan']         0.418
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz          0.878000
# 1       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8          0.000000
# 2       500062   0.166         0  1o6I8BglA6ylDMrIELygv1          0.913000
# ...

# %%
dados_artistas.head()
# Out:
#    mode  count  acousticness  \
# 0     1      9      0.590111
# 1     1     26      0.862538
# 2     1      7      0.856571
# 3     1     27      0.884926
# 4     1      7      0.510714
#
#                                              artists  danceability  \
# 0                   "Cats" 1981 Original London Cast      0.467222
# 1                          "Cats" 1983 Broadway Cast      0.441731
# 2        "Fiddler On The Roof” Motion Picture Chorus      0.348286
# 3     "Fiddler On The Roof” Motion Picture Orchestra      0.425074
# 4  "Joseph And The Amazing Technicolor Dreamcoat"...      0.467143
#
#      duration_ms    energy  instrumentalness  liveness   loudness  \
# 0  250318.555556  0.394003          0.011400  0.290833 -14.448000
# 1  287280.000000  0.406808          0.081158  0.315215 -10.690000
# 2  328920.000000  0.286571          0.024593  0.325786 -15.230714
# 3  262890.962963  0.245770          0.073587  0.275481 -15.639370
# ...

# %%
dados_com_genero.head()
# Out:
#            genres                                            artists  \
# 0  ['show tunes']                   "Cats" 1981 Original London Cast
# 1              []                          "Cats" 1983 Broadway Cast
# 2              []        "Fiddler On The Roof” Motion Picture Chorus
# 3              []     "Fiddler On The Roof” Motion Picture Orchestra
# 4              []  "Joseph And The Amazing Technicolor Dreamcoat"...
#
#    acousticness  danceability    duration_ms    energy  instrumentalness  \
# 0      0.590111      0.467222  250318.555556  0.394003          0.011400
# 1      0.862538      0.441731  287280.000000  0.406808          0.081158
# 2      0.856571      0.348286  328920.000000  0.286571          0.024593
# 3      0.884926      0.425074  262890.962963  0.245770          0.073587
# 4      0.510714      0.467143  270436.142857  0.488286          0.009400
#
#    liveness   loudness  speechiness       tempo   valence  popularity  key  \
# ...

# %%
dados_generos.head()
# Out:
#    mode                  genres  acousticness  danceability   duration_ms  \
# 0     1  21st century classical      0.979333      0.162883  1.602977e+05
# 1     1                   432hz      0.494780      0.299333  1.048887e+06
# 2     1                   8-bit      0.762000      0.712000  1.151770e+05
# 3     1                      []      0.651417      0.529093  2.328809e+05
# 4     1              a cappella      0.676557      0.538961  1.906285e+05
#
#      energy  instrumentalness  liveness   loudness  speechiness       tempo  \
# 0  0.071317          0.606834  0.361600 -31.514333     0.040567   75.336500
# 1  0.450678          0.477762  0.131000 -16.854000     0.076817  120.285667
# 2  0.818000          0.876000  0.126000  -9.180000     0.047000  133.444000
# 3  0.419146          0.205309  0.218696 -12.288965     0.107872  112.857352
# 4  0.316434          0.003003  0.172254 -12.479387     0.082851  112.110362
#
#     valence  popularity  key
# 0  0.103783   27.833333    6
# ...

# %%
dados_generos.genres.value_counts()
# Out:
# 21st century classical    1
# north carolina roots      1
# nordic soundtrack         1
# norman ok indie           1
# norsk lovsang             1
#                          ..
# ethio-jazz                1
# ethiopian pop             1
# ethnomusicology           1
# ethnotronica              1
# zydeco                    1
# Name: genres, Length: 2973, dtype: int64

# %%
dados_com_genero.genres.value_counts()
# Out:
# []                                                                                     9857
# ['movie tunes']                                                                          69
# ['show tunes']                                                                           63
# ['hollywood']                                                                            56
# ['orchestral performance']                                                               50
#                                                                                        ...
# ['nordic orchestra']                                                                      1
# ['avant-garde', 'contemporary classical', 'hungarian contemporary classical']             1
# ['conscious hip hop', 'dancehall', 'lovers rock', 'modern reggae', 'reggae fusion']       1
# ['classic swedish pop', 'danspunk', 'swedish pop']                                        1
# ...

# %%
dados_artistas[dados_artistas['artists'] == 'The Beatles']
# Out:
#        mode  count  acousticness      artists  danceability    duration_ms  \
# 24346     1    817      0.359534  The Beatles      0.522404  174591.257038
#
#          energy  instrumentalness  liveness  loudness  speechiness  \
# 24346  0.546576          0.052255  0.221973 -9.687188     0.053337
#
#             tempo   valence  popularity  key
# 24346  121.252759  0.619537   47.203182    0

# %%
dados_artistas[dados_artistas['artists'] == 'Ed Sheeran']
# Out:
#       mode  count  acousticness     artists  danceability    duration_ms  \
# 7018     1    145      0.414673  Ed Sheeran      0.663993  240009.310345
#
#         energy  instrumentalness  liveness  loudness  speechiness       tempo  \
# 7018  0.497108          0.000246  0.176846 -8.051876     0.077952  103.165979
#
#        valence  popularity  key
# 7018  0.509055   66.234483    8

# %%
dados_artistas[dados_artistas['artists'] == 'Oasis']
# Out:
#        mode  count  acousticness artists  danceability  duration_ms   energy  \
# 18456     1     80      0.097472   Oasis       0.30519   283008.025  0.81475
#
#        instrumentalness  liveness  loudness  speechiness       tempo  \
# 18456          0.118283   0.31306  -4.48025      0.05372  125.774325
#
#         valence  popularity  key
# 18456  0.280135      55.975    2

# %%
dados_artistas[dados_artistas['artists'] == 'Justin Bieber']
# Out:
#        mode  count  acousticness        artists  danceability    duration_ms  \
# 12919     1    180       0.25454  Justin Bieber      0.631111  216574.194444
#
#          energy  instrumentalness  liveness  loudness  speechiness  \
# 12919  0.626001           0.00382  0.172881 -6.694444     0.082086
#
#             tempo   valence  popularity  key
# 12919  122.811217  0.540914   65.133333    0

# %%
dados_artistas.sort_values('danceability', ascending=False)
# Out:
#        mode  count  acousticness                                     artists  \
# 27871     1      2      0.145000                                    Young Bo
# 27874     1      1      0.145000                                  Young Boss
# 10672     1      2      0.212000                                  ITSOKTOCRY
# 87        0      2      0.671000                                    347aidan
# 985       1      2      0.000143                                     Ambjaay
# ...     ...    ...           ...                                         ...
# 7913      0      2      0.962000                                  Fabricants
# 20302     1      2      0.127000                                    Rain Spa
# 25790     0      2      0.001190  The White Noise Zen & Meditation Sound Lab
# 1504      1      2      0.000000                   Appliances for Meditation
# 9868      1      2      0.908000                                  HI-FI CAMP
#
# ...

# %%
dados.head()
# Out:
#    valence  year  acousticness  \
# 0   0.0594  1921         0.982
# 1   0.9630  1921         0.732
# 2   0.0394  1921         0.961
# 3   0.1650  1921         0.967
# 4   0.2530  1921         0.957
#
#                                              artists  danceability  \
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                     ['Dennis Day']         0.819
# 2  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                   ['Frank Parker']         0.275
# 4                                     ['Phil Regan']         0.418
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz          0.878000
# 1       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8          0.000000
# 2       500062   0.166         0  1o6I8BglA6ylDMrIELygv1          0.913000
# ...

# %%
dados[dados['name'] == 'Baby']
# Out:
#         valence  year  acousticness  \
# 11485    0.2740  1979        0.9600
# 17629    0.5350  2010        0.0401
# 28492    0.5090  1969        0.5080
# 33455    0.8290  1994        0.0236
# 34929    0.4600  2002        0.0084
# 44684    0.8860  1957        0.6590
# 46919    0.3100  1968        0.3860
# 55649    0.3360  2012        0.4350
# 57378    0.4520  2020        0.0799
# 74873    0.4600  2019        0.0957
# 79484    0.3250  1955        0.9060
# 90163    0.8640  2009        0.0498
# 100255   0.3650  1977        0.5620
# 100302   0.3270  1978        0.7040
# 108765   0.7200  2020        0.3660
# 114841   0.7860  1970        0.2390
# 118668   0.8900  1989        0.1580
# 144761   0.5770  1965        0.9260
# 154198   0.0588  2013        0.2370
#
#                                           artists  danceability  duration_ms  \
# 11485                    ['Donnie & Joe Emerson']         0.508       250533
# ...
